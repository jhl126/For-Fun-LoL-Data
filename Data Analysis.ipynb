# %%
# %reload_ext nb_black

import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot

# %matplotlib inline
import os

print(os.getcwd())

print(os.listdir(os.getcwd()))
# Out:
# C:\Users\jlim7\OneDrive\Documents\GitHub\For-Fun-LoL-Data
# ['.git', '.gitignore', '.ipynb_checkpoints', 'Data Analysis.ipynb', 'high_diamond_ranked_10min.csv', 'Lol Data.zip', 'LoL EDA.ipynb', 'README.md']

# %%
# the data set contains stats 10 min into diamond ranked games (~10k)
# data obtained from https://www.kaggle.com/bobbyscience/league-of-legends-diamond-ranked-games-10-min
lol = pd.read_csv("high_diamond_ranked_10min.csv")
lol.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
#    redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                   0         16567          6.8               17047
# 1                   1         17620          6.8               17438
# 2                   0         17285          6.8               17254
# 3                   0         16478          7.0               17961
# 4                   0         17404          7.0               18313
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                    197                           55         -643
# 1                    240                           52         2908
# 2                    203                           28         1172
# 3                    235                           47         1321
# 4                    225                           67         1004
#
#    redExperienceDiff  redCSPerMin  redGoldPerMin
# 0                  8         19.7         1656.7
# 1               1173         24.0         1762.0
# 2               1033         20.3         1728.5
# 3                  7         23.5         1647.8
# 4               -230         22.5         1740.4
#
# [5 rows x 40 columns]

# %%
### Drop all red columns, focus solely on blue side.
blue_lol = lol[lol.columns.drop(list(lol.filter(regex="red")))]
blue_lol.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
#    blueTowersDestroyed  blueTotalGold  blueAvgLevel  blueTotalExperience  \
# 0                    0          17210           6.6                17039
# 1                    0          14712           6.6                16265
# 2                    0          16113           6.4                16221
# 3                    0          15157           7.0                17954
# 4                    0          16400           7.0                18543
#
#    blueTotalMinionsKilled  blueTotalJungleMinionsKilled  blueGoldDiff  \
# 0                     195                            36           643
# 1                     174                            43         -2908
# 2                     186                            46         -1172
# 3                     201                            55         -1321
# 4                     210                            57         -1004
#
#    blueExperienceDiff  blueCSPerMin  blueGoldPerMin
# 0                  -8          19.5          1721.0
# 1               -1173          17.4          1471.2
# 2               -1033          18.6          1611.3
# 3                  -7          20.1          1515.7
# 4                 230          21.0          1640.0
#
# [5 rows x 21 columns]

# %%
win = blue_lol[blue_lol["blueWins"] == 1]
lose = blue_lol[blue_lol["blueWins"] == 0]

# %%
# kruskal test indicates there is a significant difference between bluewards placed for games won and lost
stats.kruskal(win["blueWardsPlaced"], lose["blueWardsPlaced"])
# Out:
# KruskalResult(statistic=19.185571393386578, pvalue=1.1860650321130626e-05)

# %%
def cles_ind(x1, x2):
    x1 = np.array(x1)
    x2 = np.array(x2)

    diff = x1[:, None] - x2
    cles = max((diff < 0).sum(), (diff > 0).sum()) / diff.size

    return cles

# %%
# shows if a random value was chosen from wins bluewardsplaced there is a 49% chance it is greater than lose bluewardsplaced
cles_ind(win["blueWardsPlaced"], lose["blueWardsPlaced"])
# Out:
# 0.49013253645603
